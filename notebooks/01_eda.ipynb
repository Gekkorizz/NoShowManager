# %% [markdown]
# # Exploratory Data Analysis
#
# In this notebook, we analyze the No-Show dataset to find patterns.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load Data
df = pd.read_csv('../data/processed/no_show_clean.csv')
df.head()

# %%
# EDA Logic (Placeholder for Analyst work)
